# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import json

# %%
endpoint_url = "https://query.wikidata.org/sparql"

# SPARQL: Get all mushrooms (with any of P783–P789 properties) and their English Wikipedia article
query = """
SELECT DISTINCT ?item ?itemLabel ?article
WHERE {
  # ?item (wdt:P783|wdt:P784|wdt:P785|wdt:P786|wdt:P787|wdt:P788|wdt:P789) [] .
  
  OPTIONAL {
    # ?article schema:about ?item ;
             schema:isPartOf <https://en.wikipedia.org/> .
  }

  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
"""

def get_results(endpoint_url, query):
    user_agent = f"WDQS-example Python/{sys.version_info[0]}.{sys.version_info[1]}"
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

try:
    results = get_results(endpoint_url, query)
    bindings = results["results"]["bindings"]
    print(f"Successfully fetched {len(bindings)} results.\n")

    # Extract mushroom name and article link
    data = []
    for result in bindings:
        name = result["itemLabel"]["value"]
        article = result.get("article", {}).get("value", None)
        if article:  # Only keep those with an article
            data.append({"mushroom": name, "article": article})

    # Display nicely
    df = pd.DataFrame(data)
    print(df.head(10))

except Exception as e:
    print(f"An error occurred: {e}")

# Save as json file
with open("mushroom_data.json", "w") as f:
    json.dump(data, f, indent=2)

# Save as csv file
df.to_csv("data/mushroom_data.csv", index=False)

# Save as json file
with open("data/mushroom_data.json", "w") as f:
    json.dump(data, f, indent=2)
# Out:
# Successfully fetched 1342 results.
#
#                    mushroom                                            article
# 0          Russula maculata     https://en.wikipedia.org/wiki/Russula_maculata
# 1            Russula vinosa       https://en.wikipedia.org/wiki/Russula_vinosa
# 2  Gymnopilus pseudofulgens  https://en.wikipedia.org/wiki/Gymnopilus_pseud...
# 3    Gymnopilus josserandii  https://en.wikipedia.org/wiki/Gymnopilus_josse...
# 4  Albatrellus subrubescens  https://en.wikipedia.org/wiki/Albatrellus_subr...
# 5       Lactarius lignyotus  https://en.wikipedia.org/wiki/Lactarius_lignyotus
# 6             Amanita verna        https://en.wikipedia.org/wiki/Amanita_verna
# 7            lethal webcaps  https://en.wikipedia.org/wiki/Cortinarius_rube...
# 8         Russula betularum    https://en.wikipedia.org/wiki/Russula_betularum
# 9                  Galerina             https://en.wikipedia.org/wiki/Galerina

# %%
# Save as csv file
df.to_csv("data/mushroom_data.csv", index=False)

# Save as json file
with open("data/mushroom_data.json", "w") as f:
    json.dump(data, f, indent=2)

# %%
# Save as json file
import json
with open("mushroom_data.json", "w") as f:
    json.dump(data, f, indent=2)

# %%
# Print number of results
print(f"Number of results: {len(results['results']['bindings'])}")
# Out:
# Number of results: 1342

# %%
import os, time, requests, urllib.parse, json, re

API_URL = "https://en.wikipedia.org/w/api.php"
SAVE_DIR = "data/raw_articles_wikitext"
os.makedirs(SAVE_DIR, exist_ok=True)

# --- Load your Wikidata-derived JSON ---
with open("mushroom_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)
print(f"Number of entries in JSON file: {len(data)}")

# Extract titles from article URLs
def extract_title(article_url):
    """Extract the Wikipedia page title from a full URL."""
    return urllib.parse.unquote(article_url.split("/")[-1])

titles = []
for entry in data:
    article_url = entry.get("article")
    if article_url and article_url.startswith("https://en.wikipedia.org/wiki/"):
        titles.append(extract_title(article_url))
    else:
        print(f"⚠️ Skipping invalid or missing article for: {entry.get('mushroom', 'Unknown')}")

# --- User-Agent (Wikipedia requirement) ---
session = requests.Session()
session.headers.update({
    "User-Agent": "DTU-MushroomGraph/1.0 (contact: your.email@example.com)"
})

def get_wikitext(title):
    """Fetch the full wikitext of a Wikipedia page."""
    params = {
        "action": "query",
        "format": "json",
        "formatversion": "2",
        "redirects": "1",
        "prop": "revisions",
        "rvprop": "content",
        "rvslots": "main",
        "titles": title
    }
    r = session.get(API_URL, params=params, timeout=30)
    if r.status_code != 200:
        return None
    js = r.json()
    pages = js.get("query", {}).get("pages", [])
    if not pages or "missing" in pages[0]:
        return None
    return pages[0]["revisions"][0]["slots"]["main"]["content"]

def save_wikitext(title):
    """Download and save the wikitext for a Wikipedia article title."""
    safe = urllib.parse.unquote(title).replace("/", "_")
    path = os.path.join(SAVE_DIR, f"{safe}.txt")

    # Skip if file already exists
    if os.path.exists(path):
        print(f"⏭️  Skipping {title} (already exists)")
        return True

    text = get_wikitext(title)
    if not text:
        print(f"❌ Failed to get {title}")
        return False

    # Remove embedded image/file references
    text = re.sub(r"\[\[(?:File|Image):[^\]]+\]\]", "", text)

    with open(path, "w", encoding="utf-8") as f:
        f.write(text)

    time.sleep(0.5)  # be polite to the API
    return True

failed = []
for i, title in enumerate(titles, start=1):
    ok = save_wikitext(title)
    status = "Saved" if ok else "Failed"
    print(f"[{i}/{len(titles)}] {status} {title}")
    if not ok:
        failed.append(title)

if failed:
    os.makedirs("data", exist_ok=True)
    with open("data/failed_wikitext.json", "w", encoding="utf-8") as f:
        json.dump(failed, f, indent=2)
    print(f"Completed with {len(failed)} failures.")
else:
    print("Completed successfully.")
# Out:
# Number of entries in JSON file: 1161
# ⏭️  Skipping Russula_maculata (already exists)
# [1/1161] Saved Russula_maculata
# ⏭️  Skipping Russula_vinosa (already exists)
# [2/1161] Saved Russula_vinosa
# ⏭️  Skipping Gymnopilus_pseudofulgens (already exists)
# [3/1161] Saved Gymnopilus_pseudofulgens
# ⏭️  Skipping Gymnopilus_josserandii (already exists)
# [4/1161] Saved Gymnopilus_josserandii
# ⏭️  Skipping Albatrellus_subrubescens (already exists)
# [5/1161] Saved Albatrellus_subrubescens
# ⏭️  Skipping Lactarius_lignyotus (already exists)
# [6/1161] Saved Lactarius_lignyotus
# ⏭️  Skipping Amanita_verna (already exists)
# [7/1161] Saved Amanita_verna
# ⏭️  Skipping Cortinarius_rubellus (already exists)
# [8/1161] Saved Cortinarius_rubellus
# ⏭️  Skipping Russula_betularum (already exists)
# [9/1161] Saved Russula_betularum
# ⏭️  Skipping Galerina (already exists)
# [10/1161] Saved Galerina
# ⏭️  Skipping Tricholoma_sulphureum (already exists)
# [11/1161] Saved Tricholoma_sulphureum
# ⏭️  Skipping Amanita_muscaria_var._guessowii (already exists)
# [12/1161] Saved Amanita_muscaria_var._guessowii
# ⏭️  Skipping Amanita_ocreata (already exists)
# [13/1161] Saved Amanita_ocreata
# ⏭️  Skipping Armillaria (already exists)
# [14/1161] Saved Armillaria
# ⏭️  Skipping Tricholoma_atrosquamosum (already exists)
# [15/1161] Saved Tricholoma_atrosquamosum
# ⏭️  Skipping Tuber_aestivum (already exists)
# [16/1161] Saved Tuber_aestivum
# ⏭️  Skipping Agaricus_pilatianus (already exists)
# [17/1161] Saved Agaricus_pilatianus
# ⏭️  Skipping Cortinarius_traganus (already exists)
# [18/1161] Saved Cortinarius_traganus
# ⏭️  Skipping Psilocybe_liniformans_var._americana (already exists)
# [19/1161] Saved Psilocybe_liniformans_var._americana
# ⏭️  Skipping Inocybe_tricolor (already exists)
# [20/1161] Saved Inocybe_tricolor
# ⏭️  Skipping Inocybe_aeruginascens (already exists)
# [21/1161] Saved Inocybe_aeruginascens
# ⏭️  Skipping Nidulariaceae (already exists)
# [22/1161] Saved Nidulariaceae
# ⏭️  Skipping Pluteus_cyanopus (already exists)
# [23/1161] Saved Pluteus_cyanopus
# ⏭️  Skipping Mutinus_borneensis (already exists)
# [24/1161] Saved Mutinus_borneensis
# ⏭️  Skipping Lycoperdon_perlatum (already exists)
# [25/1161] Saved Lycoperdon_perlatum
# ⏭️  Skipping Trametes_suaveolens (already exists)
# [26/1161] Saved Trametes_suaveolens
# ⏭️  Skipping Pleurotus_ostreatus (already exists)
# [27/1161] Saved Pleurotus_ostreatus
# ⏭️  Skipping Stereum_hirsutum (already exists)
# [28/1161] Saved Stereum_hirsutum
# ⏭️  Skipping Amanita_strobiliformis (already exists)
# [29/1161] Saved Amanita_strobiliformis
# ⏭️  Skipping Gyroporus_cyanescens (already exists)
# [30/1161] Saved Gyroporus_cyanescens
# ⏭️  Skipping Russula_claroflava (already exists)
# [31/1161] Saved Russula_claroflava
# ⏭️  Skipping Amanita_gemmata (already exists)
# [32/1161] Saved Amanita_gemmata
# ⏭️  Skipping Tricholoma_pardinum (already exists)
# [33/1161] Saved Tricholoma_pardinum
# ⏭️  Skipping Gomphidius_roseus (already exists)
# [34/1161] Saved Gomphidius_roseus
# ⏭️  Skipping Coprinopsis_lagopus (already exists)
# [35/1161] Saved Coprinopsis_lagopus
# [36/1161] Saved Paralepistopsis_acromelalga
# ⏭️  Skipping Cortinarius_violaceus (already exists)
# [37/1161] Saved Cortinarius_violaceus
# ⏭️  Skipping Leccinum_scabrum (already exists)
# [38/1161] Saved Leccinum_scabrum
# ⏭️  Skipping Coprinellus_disseminatus (already exists)
# [39/1161] Saved Coprinellus_disseminatus
# ⏭️  Skipping Armillaria_gallica (already exists)
# [40/1161] Saved Armillaria_gallica
# ⏭️  Skipping Fistulina_hepatica (already exists)
# [41/1161] Saved Fistulina_hepatica
# ⏭️  Skipping Calocera_cornea (already exists)
# [42/1161] Saved Calocera_cornea
# ⏭️  Skipping Boletellus_ananas (already exists)
# [43/1161] Saved Boletellus_ananas
# ⏭️  Skipping Hebeloma_crustuliniforme (already exists)
# [44/1161] Saved Hebeloma_crustuliniforme
# [45/1161] Saved Ramaria_flava
# [46/1161] Saved Gomphidius_maculatus
# [47/1161] Saved Imperator_torosus
# ⏭️  Skipping Cortinarius_praestans (already exists)
# [48/1161] Saved Cortinarius_praestans
# ⏭️  Skipping Agaricus_deserticola (already exists)
# [49/1161] Saved Agaricus_deserticola
# ⏭️  Skipping Cantharellus_friesii (already exists)
# [50/1161] Saved Cantharellus_friesii
# ⏭️  Skipping Laccaria_laccata (already exists)
# [51/1161] Saved Laccaria_laccata
# ⏭️  Skipping Amanita_muscaria (already exists)
# [52/1161] Saved Amanita_muscaria
# [53/1161] Saved Leccinum_vulpinum
# ⏭️  Skipping Lactifluus_corrugis (already exists)
# [54/1161] Saved Lactifluus_corrugis
# ⏭️  Skipping Russula_emetica (already exists)
# [55/1161] Saved Russula_emetica
# ⏭️  Skipping Strobilomyces_strobilaceus (already exists)
# [56/1161] Saved Strobilomyces_strobilaceus
# ⏭️  Skipping Russula_paludosa (already exists)
# [57/1161] Saved Russula_paludosa
# ⏭️  Skipping Blusher (already exists)
# [58/1161] Saved Blusher
# [59/1161] Saved Clavulina_cristata
# [60/1161] Saved Lyophyllum_decastes
# [61/1161] Saved Pestalotiopsis_microspora
# ⏭️  Skipping Chlorophyllum_molybdites (already exists)
# [62/1161] Saved Chlorophyllum_molybdites
# [63/1161] Saved Russula_gracillima
# ⏭️  Skipping Rhodocollybia_butyracea (already exists)
# [64/1161] Saved Rhodocollybia_butyracea
# [65/1161] Saved Panellus_stipticus
# ⏭️  Skipping Entoloma_sinuatum (already exists)
# [66/1161] Saved Entoloma_sinuatum
# ⏭️  Skipping Lactarius_tabidus (already exists)
# [67/1161] Saved Lactarius_tabidus
# [68/1161] Saved Russula_violeipes
# ⏭️  Skipping Hygrocybe_conica (already exists)
# [69/1161] Saved Hygrocybe_conica
# ⏭️  Skipping Omphalotus_olearius (already exists)
# [70/1161] Saved Omphalotus_olearius
# [71/1161] Saved Lyophyllum_shimeji
# ⏭️  Skipping Agaricus_semotus (already exists)
# [72/1161] Saved Agaricus_semotus
# ⏭️  Skipping Lactarius_sanguifluus (already exists)
# [73/1161] Saved Lactarius_sanguifluus
# [74/1161] Saved Lentinus_arcularius
# ⏭️  Skipping Catathelasma_imperiale (already exists)
# [75/1161] Saved Catathelasma_imperiale
# ⏭️  Skipping Tricholomopsis_rutilans (already exists)
# [76/1161] Saved Tricholomopsis_rutilans
# ⏭️  Skipping Russula_nobilis (already exists)
# [77/1161] Saved Russula_nobilis
# [78/1161] Saved Astraeus_hygrometricus
# ⏭️  Skipping Mycena_chlorophos (already exists)
# [79/1161] Saved Mycena_chlorophos
# [80/1161] Saved Lycoperdon_umbrinum
# [81/1161] Saved Morchella_elata
# ⏭️  Skipping Russula_caerulea (already exists)
# [82/1161] Saved Russula_caerulea
# ⏭️  Skipping Cortinarius_varius (already exists)
# [83/1161] Saved Cortinarius_varius
# [84/1161] Saved Xerocomus_subtomentosus
# ⏭️  Skipping Cortinarius_caperatus (already exists)
# [85/1161] Saved Cortinarius_caperatus
# ⏭️  Skipping Hypholoma_lateritium (already exists)
# [86/1161] Saved Hypholoma_lateritium
# [87/1161] Saved Pycnoporus_cinnabarinus
# [88/1161] Saved Suillus_plorans
# ⏭️  Skipping Russula_ochroleuca (already exists)
# [89/1161] Saved Russula_ochroleuca
# ⏭️  Skipping Tylopilus_felleus (already exists)
# [90/1161] Saved Tylopilus_felleus
# ⏭️  Skipping Ramaria_stricta (already exists)
# [91/1161] Saved Ramaria_stricta
# ⏭️  Skipping Russula_nigricans (already exists)
# [92/1161] Saved Russula_nigricans
# ⏭️  Skipping Volvariella_volvacea (already exists)
# [93/1161] Saved Volvariella_volvacea
# ⏭️  Skipping Lactarius_glyciosmus (already exists)
# [94/1161] Saved Lactarius_glyciosmus
# ⏭️  Skipping Cortinarius_cinnamomeus (already exists)
# [95/1161] Saved Cortinarius_cinnamomeus
# ⏭️  Skipping Lactarius_pubescens (already exists)
# [96/1161] Saved Lactarius_pubescens
# ⏭️  Skipping Amanita_phalloides (already exists)
# [97/1161] Saved Amanita_phalloides
# ⏭️  Skipping Cantharellus_cibarius (already exists)
# [98/1161] Saved Cantharellus_cibarius
# [99/1161] Saved Lycoperdon_echinatum
# [100/1161] Saved Tuber_melanosporum
# [101/1161] Saved Strobilurus_esculentus
# ⏭️  Skipping Mycena (already exists)
# [102/1161] Saved Mycena
# [103/1161] Saved Agaricus_silvaticus
# ⏭️  Skipping Morchella_esculenta (already exists)
# [104/1161] Saved Morchella_esculenta
# ⏭️  Skipping Agrocybe_praecox (already exists)
# [105/1161] Saved Agrocybe_praecox
# ⏭️  Skipping Tricholoma_saponaceum (already exists)
# [106/1161] Saved Tricholoma_saponaceum
# ⏭️  Skipping Psilocybe_mexicana (already exists)
# [107/1161] Saved Psilocybe_mexicana
# ⏭️  Skipping Craterellus_lutescens (already exists)
# [108/1161] Saved Craterellus_lutescens
# ⏭️  Skipping Suillus_granulatus (already exists)
# [109/1161] Saved Suillus_granulatus
# ⏭️  Skipping Psilocybe_azurescens (already exists)
# [110/1161] Saved Psilocybe_azurescens
# ⏭️  Skipping Amanita_magniverrucata (already exists)
# [111/1161] Saved Amanita_magniverrucata
# ⏭️  Skipping Boletus_barrowsii (already exists)
# [112/1161] Saved Boletus_barrowsii
# [113/1161] Saved Amanita_altipes
# ⏭️  Skipping Hygrophorus_eburneus (already exists)
# [114/1161] Saved Hygrophorus_eburneus
# ⏭️  Skipping Cantharellus_minor (already exists)
# [115/1161] Saved Cantharellus_minor
# ⏭️  Skipping Amanita_abrupta (already exists)
# [116/1161] Saved Amanita_abrupta
# ⏭️  Skipping Amanita_jacksonii (already exists)
# [117/1161] Saved Amanita_jacksonii
# ⏭️  Skipping Xerocomellus_zelleri (already exists)
# [118/1161] Saved Xerocomellus_zelleri
# [119/1161] Saved Amanita_orientifulva
# [120/1161] Saved Amanita_parvipantherina
# [121/1161] Saved Amanita_liquii
# ⏭️  Skipping Amanita_smithiana (already exists)
# [122/1161] Saved Amanita_smithiana
# [123/1161] Saved Strobilomyces_foveatus
# ⏭️  Skipping Coprinopsis_atramentaria (already exists)
# [124/1161] Saved Coprinopsis_atramentaria
# ⏭️  Skipping Marasmius_oreades (already exists)
# [125/1161] Saved Marasmius_oreades
# ⏭️  Skipping Hygrophorus_marzuolus (already exists)
# [126/1161] Saved Hygrophorus_marzuolus
# ⏭️  Skipping Kuehneromyces_mutabilis (already exists)
# [127/1161] Saved Kuehneromyces_mutabilis
# ⏭️  Skipping Amanita_regalis (already exists)
# [128/1161] Saved Amanita_regalis
# ⏭️  Skipping Imleria_badia (already exists)
# [129/1161] Saved Imleria_badia
# ⏭️  Skipping Suillellus_luridus (already exists)
# [130/1161] Saved Suillellus_luridus
# ⏭️  Skipping Calocybe_gambosa (already exists)
# [131/1161] Saved Calocybe_gambosa
# ⏭️  Skipping Lactarius_repraesentaneus (already exists)
# [132/1161] Saved Lactarius_repraesentaneus
# ⏭️  Skipping Agaricus_bisporus (already exists)
# [133/1161] Saved Agaricus_bisporus
# ⏭️  Skipping Agaricus_campestris (already exists)
# [134/1161] Saved Agaricus_campestris
# ⏭️  Skipping Russula_olivacea (already exists)
# [135/1161] Saved Russula_olivacea
# ⏭️  Skipping Macrolepiota_procera (already exists)
# [136/1161] Saved Macrolepiota_procera
# ⏭️  Skipping Stropharia_rugosoannulata (already exists)
# [137/1161] Saved Stropharia_rugosoannulata
# [138/1161] Saved Helvella_crispa
# [139/1161] Saved Aleuria_aurantia
# ⏭️  Skipping Ramaria_formosa (already exists)
# [140/1161] Saved Ramaria_formosa
# ⏭️  Skipping Pleurotus_pulmonarius (already exists)
# [141/1161] Saved Pleurotus_pulmonarius
# ⏭️  Skipping Mycena_haematopus (already exists)
# [142/1161] Saved Mycena_haematopus
# [143/1161] Saved Russula_fragilis
# ⏭️  Skipping Hygrophoropsis_aurantiaca (already exists)
# [144/1161] Saved Hygrophoropsis_aurantiaca
# ⏭️  Skipping Neolentinus_lepideus (already exists)
# [145/1161] Saved Neolentinus_lepideus
# ⏭️  Skipping Hypholoma_fasciculare (already exists)
# [146/1161] Saved Hypholoma_fasciculare
# [147/1161] Saved Pulveroboletus_ravenelii
# ⏭️  Skipping Phallus_rubicundus (already exists)
# [148/1161] Saved Phallus_rubicundus
# [149/1161] Saved Gyrodon_lividus
# [150/1161] Saved Scleroderma_citrinum
# [151/1161] Saved Suillus_mediterraneensis
# [152/1161] Saved Chalciporus_piperatus
# [153/1161] Saved Polyporus_umbellatus
# ⏭️  Skipping Russula_virescens (already exists)
# [154/1161] Saved Russula_virescens
# ⏭️  Skipping Psilocybe_cubensis (already exists)
# [155/1161] Saved Psilocybe_cubensis
# ⏭️  Skipping Agaricus_arvensis (already exists)
# [156/1161] Saved Agaricus_arvensis
# ⏭️  Skipping Russula_sardonia (already exists)
# [157/1161] Saved Russula_sardonia
# ⏭️  Skipping Pleurotus_citrinopileatus (already exists)
# [158/1161] Saved Pleurotus_citrinopileatus
# ⏭️  Skipping Pseudohydnum_gelatinosum (already exists)
# [159/1161] Saved Pseudohydnum_gelatinosum
# [160/1161] Saved Macrolepiota_mastoidea
# ⏭️  Skipping Pluteus (already exists)
# [161/1161] Saved Pluteus
# [162/1161] Saved Marasmiellus_ramealis
# ⏭️  Skipping Grifola_frondosa (already exists)
# [163/1161] Saved Grifola_frondosa
# ⏭️  Skipping Lactarius_indigo (already exists)
# [164/1161] Saved Lactarius_indigo
# ⏭️  Skipping Suillus_bovinus (already exists)
# [165/1161] Saved Suillus_bovinus
# [166/1161] Saved Gyroporus_castaneus
# ⏭️  Skipping Amanita_caesarea (already exists)
# [167/1161] Saved Amanita_caesarea
# [168/1161] Saved Calvatia_gigantea
# [169/1161] Saved Inonotus_hispidus
# [170/1161] Saved Coprinellus_xanthothrix
# [171/1161] Saved Helvella_lacunosa
# [172/1161] Saved Verpa_bohemica
# ⏭️  Skipping Mycena_galericulata (already exists)
# [173/1161] Saved Mycena_galericulata
# ⏭️  Skipping Lactarius_azonites (already exists)
# [174/1161] Saved Lactarius_azonites
# ⏭️  Skipping Hygrophorus_agathosmus (already exists)
# [175/1161] Saved Hygrophorus_agathosmus
# ⏭️  Skipping Tricholoma_orirubens (already exists)
# [176/1161] Saved Tricholoma_orirubens
# [177/1161] Saved Hydnellum_peckii
# [178/1161] Saved Fomitopsis_pinicola
# ⏭️  Skipping Lactarius_aurantiacus (already exists)
# [179/1161] Saved Lactarius_aurantiacus
# ⏭️  Skipping Amanita_farinosa (already exists)
# [180/1161] Saved Amanita_farinosa
# ⏭️  Skipping Amanita_flavoconia (already exists)
# [181/1161] Saved Amanita_flavoconia
# ⏭️  Skipping Paragyrodon (already exists)
# [182/1161] Saved Paragyrodon
# ⏭️  Skipping Sarcoscypha_occidentalis (already exists)
# [183/1161] Saved Sarcoscypha_occidentalis
# [184/1161] Saved Hortiboletus_rubellus
# [185/1161] Saved Crepidotus_versutus
# [186/1161] Saved Russula_acrifolia
# ⏭️  Skipping Craterellus (already exists)
# [187/1161] Saved Craterellus
# [188/1161] Saved Cordyceps_militaris
# [189/1161] Saved Daedaleopsis_confragosa
# ⏭️  Skipping Lactarius_fuliginosus (already exists)
# [190/1161] Saved Lactarius_fuliginosus
# ⏭️  Skipping Mycena_inclinata (already exists)
# [191/1161] Saved Mycena_inclinata
# ⏭️  Skipping Gomphus_clavatus (already exists)
# [192/1161] Saved Gomphus_clavatus
# ⏭️  Skipping Infundibulicybe_geotropa (already exists)
# [193/1161] Saved Infundibulicybe_geotropa
# ⏭️  Skipping Ramaria_aurea (already exists)
# [194/1161] Saved Ramaria_aurea
# [195/1161] Saved Lactarius_trivialis
# [196/1161] Saved Chroogomphus_rutilus
# [197/1161] Saved Mutinus_caninus
# ⏭️  Skipping Mycena_pura (already exists)
# [198/1161] Saved Mycena_pura
# [199/1161] Saved Lentinus_tigrinus
# ⏭️  Skipping Amanita_calyptroderma (already exists)
# [200/1161] Saved Amanita_calyptroderma
# ⏭️  Skipping Psilocybe_tampanensis (already exists)
# [201/1161] Saved Psilocybe_tampanensis
# [202/1161] Saved Amanita_cokeri
# [203/1161] Saved Psathyrella_aquatica
# ⏭️  Skipping Conocybula_cyanopus (already exists)
# [204/1161] Saved Conocybula_cyanopus
# [205/1161] Saved Entoloma_bloxamii
# [206/1161] Saved Inonotus_obliquus
# ⏭️  Skipping Amanita_lividopallescens (already exists)
# [207/1161] Saved Amanita_lividopallescens
# [208/1161] Saved Russula_decolorans
# ⏭️  Skipping Mycena_epipterygia (already exists)
# [209/1161] Saved Mycena_epipterygia
# ⏭️  Skipping Porphyrellus_porphyrosporus (already exists)
# [210/1161] Saved Porphyrellus_porphyrosporus
# ⏭️  Skipping Galerina_marginata (already exists)
# [211/1161] Saved Galerina_marginata
# [212/1161] Saved Phylloporus_pelletieri
# [213/1161] Saved Xerocomellus_chrysenteron
# ⏭️  Skipping Calocera_viscosa (already exists)
# [214/1161] Saved Calocera_viscosa
# ⏭️  Skipping Amanita_porphyria (already exists)
# [215/1161] Saved Amanita_porphyria
# ⏭️  Skipping Tricholoma_portentosum (already exists)
# [216/1161] Saved Tricholoma_portentosum
# ⏭️  Skipping Sarcodon_imbricatus (already exists)
# [217/1161] Saved Sarcodon_imbricatus
# ⏭️  Skipping Agaricus_augustus (already exists)
# [218/1161] Saved Agaricus_augustus
# ⏭️  Skipping Boletus_aereus (already exists)
# [219/1161] Saved Boletus_aereus
# ⏭️  Skipping Shaggy_parasol (already exists)
# [220/1161] Saved Shaggy_parasol
# [221/1161] Saved Lactarius_mammosus
# ⏭️  Skipping Suillus_bellinii (already exists)
# [222/1161] Saved Suillus_bellinii
# [223/1161] Saved Trametes_versicolor
# ⏭️  Skipping Clitocybe_nebularis (already exists)
# [224/1161] Saved Clitocybe_nebularis
# [225/1161] Saved Pseudoboletus_parasiticus
# ⏭️  Skipping Russula_cyanoxantha (already exists)
# [226/1161] Saved Russula_cyanoxantha
# [227/1161] Saved Armillaria_cepistipes
# [228/1161] Saved Agaricus_urinascens
# [229/1161] Saved Crepidotus_mollis
# [230/1161] Saved Hygrophorus_karstenii
# [231/1161] Saved Leccinum_duriusculum
# [232/1161] Saved Cyathus_striatus
# ⏭️  Skipping Marasmius (already exists)
# [233/1161] Saved Marasmius
# [234/1161] Saved Lactarius_chrysorrheus
# ⏭️  Skipping Russula_aurea (already exists)
# [235/1161] Saved Russula_aurea
# ⏭️  Skipping Amanita_ovoidea (already exists)
# [236/1161] Saved Amanita_ovoidea
# ⏭️  Skipping Hypholoma_capnoides (already exists)
# [237/1161] Saved Hypholoma_capnoides
# ⏭️  Skipping Lactarius_vietus (already exists)
# [238/1161] Saved Lactarius_vietus
# ⏭️  Skipping Lactarius_blennius (already exists)
# [239/1161] Saved Lactarius_blennius
# ⏭️  Skipping Suillus_viscidus (already exists)
# [240/1161] Saved Suillus_viscidus
# [241/1161] Saved Agaricus_litoralis
# ⏭️  Skipping Lactarius_scrobiculatus (already exists)
# [242/1161] Saved Lactarius_scrobiculatus
# [243/1161] Saved Lactarius_salmonicolor
# ⏭️  Skipping Agaricus_bernardii (already exists)
# [244/1161] Saved Agaricus_bernardii
# [245/1161] Saved Limacella_delicata
# [246/1161] Saved Tremella_fuciformis
# [247/1161] Saved Psathyrella_candolleana
# [248/1161] Saved Ganoderma_lucidum
# ⏭️  Skipping Coprinus_comatus (already exists)
# [249/1161] Saved Coprinus_comatus
# [250/1161] Saved Infundibulicybe_gibba
# ⏭️  Skipping Pluteus_leoninus (already exists)
# [251/1161] Saved Pluteus_leoninus
# ⏭️  Skipping Panaeolus_semiovatus_var._semiovatus (already exists)
# [252/1161] Saved Panaeolus_semiovatus_var._semiovatus
# [253/1161] Saved Trametes_pubescens
# [254/1161] Saved Cerrena_unicolor
# [255/1161] Saved Pisolithus_arhizus
# ⏭️  Skipping Panaeolus_acuminatus (already exists)
# [256/1161] Saved Panaeolus_acuminatus
# [257/1161] Saved Hericium_coralloides
# ⏭️  Skipping Agaricus_subrufescens (already exists)
# [258/1161] Saved Agaricus_subrufescens
# [259/1161] Saved Phallus_hadriani
# ⏭️  Skipping Lepiota_clypeolaria (already exists)
# [260/1161] Saved Lepiota_clypeolaria
# ⏭️  Skipping Amanita_fulva (already exists)
# [261/1161] Saved Amanita_fulva
# ⏭️  Skipping Russula_xerampelina (already exists)
# [262/1161] Saved Russula_xerampelina
# [263/1161] Saved Laetiporus_sulphureus
# [264/1161] Saved Ganoderma_applanatum
# ⏭️  Skipping Russula_fellea (already exists)
# [265/1161] Saved Russula_fellea
# ⏭️  Skipping Lepiota_brunneoincarnata (already exists)
# [266/1161] Saved Lepiota_brunneoincarnata
# ⏭️  Skipping Panaeolus_cyanescens (already exists)
# [267/1161] Saved Panaeolus_cyanescens
# ⏭️  Skipping Entoloma_rhodopolium (already exists)
# [268/1161] Saved Entoloma_rhodopolium
# [269/1161] Saved Clavaria_fragilis
# [270/1161] Saved Desarmillaria_tabescens
# [271/1161] Saved Pleurocybella_porrigens
# ⏭️  Skipping Hygrophorus_latitabundus (already exists)
# [272/1161] Saved Hygrophorus_latitabundus
# ⏭️  Skipping Cortinarius_semisanguineus (already exists)
# [273/1161] Saved Cortinarius_semisanguineus
# [274/1161] Saved Stropharia_aeruginosa
# [275/1161] Saved Geastrum_fimbriatum
# [276/1161] Saved Disciotis_venosa
# ⏭️  Skipping Amanita_excelsa_var._spissa (already exists)
# [277/1161] Saved Amanita_excelsa_var._spissa
# [278/1161] Saved Butyriboletus_subappendiculatus
# ⏭️  Skipping Russula_aeruginea (already exists)
# [279/1161] Saved Russula_aeruginea
# [280/1161] Saved Lactarius_rufus
# ⏭️  Skipping Hemileccinum_impolitum (already exists)
# [281/1161] Saved Hemileccinum_impolitum
# ⏭️  Skipping Lactifluus_piperatus (already exists)
# [282/1161] Saved Lactifluus_piperatus
# ⏭️  Skipping Hydnum_rufescens (already exists)
# [283/1161] Saved Hydnum_rufescens
# ⏭️  Skipping Lactarius_torminosus (already exists)
# [284/1161] Saved Lactarius_torminosus
# ⏭️  Skipping Russula_amethystina (already exists)
# [285/1161] Saved Russula_amethystina
# [286/1161] Saved Cystoderma_amianthinum
# [287/1161] Saved Trametes_gibbosa
# [288/1161] Saved Armillaria_mellea
# ⏭️  Skipping Amanita_virosa (already exists)
# [289/1161] Saved Amanita_virosa
# ⏭️  Skipping Omphalotus_nidiformis (already exists)
# [290/1161] Saved Omphalotus_nidiformis
# ⏭️  Skipping Psilocybe_cyanescens (already exists)
# [291/1161] Saved Psilocybe_cyanescens
# ⏭️  Skipping Imperator_rhodopurpureus (already exists)
# [292/1161] Saved Imperator_rhodopurpureus
# ⏭️  Skipping Lactarius_deterrimus (already exists)
# [293/1161] Saved Lactarius_deterrimus
# ⏭️  Skipping Psilocybe_semilanceata (already exists)
# [294/1161] Saved Psilocybe_semilanceata
# ⏭️  Skipping Russula_sanguinaria (already exists)
# [295/1161] Saved Russula_sanguinaria
# ⏭️  Skipping Matsutake (already exists)
# [296/1161] Saved Matsutake
# ⏭️  Skipping Lactarius_semisanguifluus (already exists)
# [297/1161] Saved Lactarius_semisanguifluus
# ⏭️  Skipping Paxillus_involutus (already exists)
# [298/1161] Saved Paxillus_involutus
# [299/1161] Saved Gyromitra_esculenta
# ⏭️  Skipping Clitocybe_dealbata (already exists)
# [300/1161] Saved Clitocybe_dealbata
# ⏭️  Skipping Pholiota_flammans (already exists)
# [301/1161] Saved Pholiota_flammans
# ⏭️  Skipping Boletus_pinophilus (already exists)
# [302/1161] Saved Boletus_pinophilus
# ⏭️  Skipping Tapinella_atrotomentosa (already exists)
# [303/1161] Saved Tapinella_atrotomentosa
# [304/1161] Saved Russula_heterophylla
# [305/1161] Saved Verpa_conica
# ⏭️  Skipping Agaricus_bitorquis (already exists)
# [306/1161] Saved Agaricus_bitorquis
# [307/1161] Saved Lacrymaria_lacrymabunda
# ⏭️  Skipping Amanita_hemibapha (already exists)
# [308/1161] Saved Amanita_hemibapha
# [309/1161] Saved Agaricus_californicus
# ⏭️  Skipping Amanita_subjunquillea (already exists)
# [310/1161] Saved Amanita_subjunquillea
# ⏭️  Skipping Agaricus_impudicus (already exists)
# [311/1161] Saved Agaricus_impudicus
# [312/1161] Saved Lycoperdon_mammiforme
# [313/1161] Saved Lycoperdon_curtisii
# [314/1161] Saved Suillus_cavipes
# ⏭️  Skipping Conocybe_apala (already exists)
# [315/1161] Saved Conocybe_apala
# ⏭️  Skipping Mycena_sanguinolenta (already exists)
# [316/1161] Saved Mycena_sanguinolenta
# [317/1161] Saved Clavariadelphus_truncatus
# ⏭️  Skipping Shiitake (already exists)
# [318/1161] Saved Shiitake
# [319/1161] Saved Auricularia_auricula-judae
# [320/1161] Saved Mutinus_ravenelii
# ⏭️  Skipping Amanita_zambiana (already exists)
# [321/1161] Saved Amanita_zambiana
# ⏭️  Skipping Gomphidius_glutinosus (already exists)
# [322/1161] Saved Gomphidius_glutinosus
# ⏭️  Skipping Pluteus_cervinus (already exists)
# [323/1161] Saved Pluteus_cervinus
# ⏭️  Skipping Psilocybe_aztecorum (already exists)
# [324/1161] Saved Psilocybe_aztecorum
# ⏭️  Skipping Albatrellus_ovinus (already exists)
# [325/1161] Saved Albatrellus_ovinus
# ⏭️  Skipping Coprinopsis_picacea (already exists)
# [326/1161] Saved Coprinopsis_picacea
# ⏭️  Skipping Suillus_luteus (already exists)
# [327/1161] Saved Suillus_luteus
# [328/1161] Saved Xerocomellus_pruinatus
# [329/1161] Saved Polyporus_tuberaster
# [330/1161] Saved Helvella_elastica
# [331/1161] Saved Morchella_conica
# [332/1161] Saved Suillus_placidus
# [333/1161] Saved Leccinum_holopus
# ⏭️  Skipping Inocybe_geophylla (already exists)
# [334/1161] Saved Inocybe_geophylla
# [335/1161] Saved Gymnopilus_karrara
# ⏭️  Skipping Tricholoma_equestre (already exists)
# [336/1161] Saved Tricholoma_equestre
# [337/1161] Saved Ramaria_botrytis
# ⏭️  Skipping Panaeolus_papilionaceus (already exists)
# [338/1161] Saved Panaeolus_papilionaceus
# [339/1161] Saved Xerocomellus_porosporus
# [340/1161] Saved Clathrus_columnatus
# ⏭️  Skipping Phlegmacium_triumphans (already exists)
# [341/1161] Saved Phlegmacium_triumphans
# ⏭️  Skipping Cortinarius_anomalus (already exists)
# [342/1161] Saved Cortinarius_anomalus
# ⏭️  Skipping Cortinarius_delibutus (already exists)
# [343/1161] Saved Cortinarius_delibutus
# [344/1161] Saved Hydnellum_suaveolens
# [345/1161] Saved Humaria_hemisphaerica
# ⏭️  Skipping Marasmius_rotula (already exists)
# [346/1161] Saved Marasmius_rotula
# [347/1161] Saved Geastrum_triplex
# ⏭️  Skipping Amanita_crocea (already exists)
# [348/1161] Saved Amanita_crocea
# ⏭️  Skipping Pholiota_squarrosa (already exists)
# [349/1161] Saved Pholiota_squarrosa
# ⏭️  Skipping Lactarius_controversus (already exists)
# [350/1161] Saved Lactarius_controversus
# ⏭️  Skipping Polyozellus (already exists)
# [351/1161] Saved Polyozellus
# [352/1161] Saved Rhodocybe_gemina
# ⏭️  Skipping Suillus_variegatus (already exists)
# [353/1161] Saved Suillus_variegatus
# [354/1161] Saved Cyathus
# ⏭️  Skipping Clitopilus_prunulus (already exists)
# [355/1161] Saved Clitopilus_prunulus
# [356/1161] Saved Lycoperdon_excipuliforme
# ⏭️  Skipping Lactarius_quietus (already exists)
# [357/1161] Saved Lactarius_quietus
# [358/1161] Saved Stropharia_hornemannii
# ⏭️  Skipping Suillus_sibiricus (already exists)
# [359/1161] Saved Suillus_sibiricus
# [360/1161] Saved Russula_mustelina
# [361/1161] Saved Leccinum_variicolor
# [362/1161] Saved Tuber_brumale
# ⏭️  Skipping Phaeolepiota (already exists)
# [363/1161] Saved Phaeolepiota
# ⏭️  Skipping Craterellus_tubaeformis (already exists)
# [364/1161] Saved Craterellus_tubaeformis
# ⏭️  Skipping Flammulina_velutipes (already exists)
# [365/1161] Saved Flammulina_velutipes
# ⏭️  Skipping Laccaria_bicolor (already exists)
# [366/1161] Saved Laccaria_bicolor
# ⏭️  Skipping Suillus_grevillei (already exists)
# [367/1161] Saved Suillus_grevillei
# [368/1161] Saved Pleurotus_cornucopiae
# ⏭️  Skipping Russula_delica (already exists)
# [369/1161] Saved Russula_delica
# [370/1161] Saved Clavariadelphus_pistillaris
# ⏭️  Skipping Agaricus_silvicola (already exists)
# [371/1161] Saved Agaricus_silvicola
# ⏭️  Skipping Russula_vesca (already exists)
# [372/1161] Saved Russula_vesca
# ⏭️  Skipping Craterellus_cornucopioides (already exists)
# [373/1161] Saved Craterellus_cornucopioides
# ⏭️  Skipping Lactarius_helvus (already exists)
# [374/1161] Saved Lactarius_helvus
# ⏭️  Skipping Lactarius_pallidus (already exists)
# [375/1161] Saved Lactarius_pallidus
# ⏭️  Skipping Leucocoprinus_birnbaumii (already exists)
# [376/1161] Saved Leucocoprinus_birnbaumii
# [377/1161] Saved Psathyrella_piluliformis
# ⏭️  Skipping Mycena_leptocephala (already exists)
# [378/1161] Saved Mycena_leptocephala
# [379/1161] Saved Macrolepiota_excoriata
# [380/1161] Saved Russula_versicolor
# [381/1161] Saved Russula_risigallina
# ⏭️  Skipping Cortinarius_mucosus (already exists)
# [382/1161] Saved Cortinarius_mucosus
# ⏭️  Skipping Cortinarius_collinitus (already exists)
# [383/1161] Saved Cortinarius_collinitus
# [384/1161] Saved Scleroderma_cepa
# ⏭️  Skipping Agaricus_moelleri (already exists)
# [385/1161] Saved Agaricus_moelleri
# ⏭️  Skipping Amanita_brunnescens (already exists)
# [386/1161] Saved Amanita_brunnescens
# [387/1161] Saved Lycoperdon_nigrescens
# ⏭️  Skipping Agaricus_xanthodermus (already exists)
# [388/1161] Saved Agaricus_xanthodermus
# ⏭️  Skipping Lactifluus_vellereus (already exists)
# [389/1161] Saved Lactifluus_vellereus
# [390/1161] Saved Hygrophorus_hypothejus
# [391/1161] Saved Cortinarius_orellanus
# ⏭️  Skipping Panaeolus_foenisecii (already exists)
# [392/1161] Saved Panaeolus_foenisecii
# ⏭️  Skipping Cantharellus (already exists)
# [393/1161] Saved Cantharellus
# [394/1161] Saved Armillaria_ostoyae
# ⏭️  Skipping Saproamanita_vittadinii (already exists)
# [395/1161] Saved Saproamanita_vittadinii
# ⏭️  Skipping Amanita_vaginata (already exists)
# [396/1161] Saved Amanita_vaginata
# ⏭️  Skipping Echinoderma_asperum (already exists)
# [397/1161] Saved Echinoderma_asperum
# ⏭️  Skipping Rhodocollybia_maculata (already exists)
# [398/1161] Saved Rhodocollybia_maculata
# [399/1161] Saved Lepista_irina
# ⏭️  Skipping Clitocybe_odora (already exists)
# [400/1161] Saved Clitocybe_odora
# [401/1161] Saved Russula_rosea
# [402/1161] Saved Alloclavaria_purpurea
# ⏭️  Skipping Conocybe_tenera (already exists)
# [403/1161] Saved Conocybe_tenera
# ⏭️  Skipping Mycena_metata (already exists)
# [404/1161] Saved Mycena_metata
# ⏭️  Skipping Pleurotus_eryngii (already exists)
# [405/1161] Saved Pleurotus_eryngii
# [406/1161] Saved Russula_integra
# ⏭️  Skipping Rubroboletus_legaliae (already exists)
# [407/1161] Saved Rubroboletus_legaliae
# ⏭️  Skipping Tricholoma_sejunctum (already exists)
# [408/1161] Saved Tricholoma_sejunctum
# ⏭️  Skipping Agaricus_placomyces (already exists)
# [409/1161] Saved Agaricus_placomyces
# [410/1161] Saved Bjerkandera_adusta
# ⏭️  Skipping Volvariella_bombycina (already exists)
# [411/1161] Saved Volvariella_bombycina
# [412/1161] Saved Leccinum_versipelle
# [413/1161] Saved Mutinus_elegans
# ⏭️  Skipping Mycena_acicula (already exists)
# [414/1161] Saved Mycena_acicula
# [415/1161] Saved Bovista_nigrescens
# ⏭️  Skipping Phallus_indusiatus (already exists)
# [416/1161] Saved Phallus_indusiatus
# ⏭️  Skipping Armillaria_luteobubalina (already exists)
# [417/1161] Saved Armillaria_luteobubalina
# [418/1161] Saved Stereum_ostrea
# ⏭️  Skipping Suillus_brevipes (already exists)
# [419/1161] Saved Suillus_brevipes
# ⏭️  Skipping Inocybe_hystrix (already exists)
# [420/1161] Saved Inocybe_hystrix
# ⏭️  Skipping Amanita_echinocephala (already exists)
# [421/1161] Saved Amanita_echinocephala
# [422/1161] Saved Hebeloma_sinapizans
# [423/1161] Saved Hygrophorus_russula
# ⏭️  Skipping Lentinellus_cochleatus (already exists)
# [424/1161] Saved Lentinellus_cochleatus
# ⏭️  Skipping Clitocybe_rivulosa (already exists)
# [425/1161] Saved Clitocybe_rivulosa
# [426/1161] Saved Geastrum_quadrifidum
# ⏭️  Skipping Lepiota_helveola (already exists)
# [427/1161] Saved Lepiota_helveola
# ⏭️  Skipping Mycena_polygramma (already exists)
# [428/1161] Saved Mycena_polygramma
# ⏭️  Skipping Crinipellis_zonata (already exists)
# [429/1161] Saved Crinipellis_zonata
# ⏭️  Skipping Cantharellus_appalachiensis (already exists)
# [430/1161] Saved Cantharellus_appalachiensis
# ⏭️  Skipping Cantharellus_subalbidus (already exists)
# [431/1161] Saved Cantharellus_subalbidus
# ⏭️  Skipping Cortinarius_vanduzerensis (already exists)
# [432/1161] Saved Cortinarius_vanduzerensis
# [433/1161] Saved Lactarius_pseudomucidus
# ⏭️  Skipping Leccinum_manzanitae (already exists)
# [434/1161] Saved Leccinum_manzanitae
# ⏭️  Skipping Leucocoprinus_fragilissimus (already exists)
# [435/1161] Saved Leucocoprinus_fragilissimus
# ⏭️  Skipping Leucoagaricus_americanus (already exists)
# [436/1161] Saved Leucoagaricus_americanus
# ⏭️  Skipping Pholiotina_smithii (already exists)
# [437/1161] Saved Pholiotina_smithii
# ⏭️  Skipping Tylopilus_tabacinus (already exists)
# [438/1161] Saved Tylopilus_tabacinus
# [439/1161] Saved Boletus_purpureus
# ⏭️  Skipping Gymnopilus_liquiritiae (already exists)
# [440/1161] Saved Gymnopilus_liquiritiae
# ⏭️  Skipping Lepiota_subincarnata (already exists)
# [441/1161] Saved Lepiota_subincarnata
# ⏭️  Skipping Cantharellus_lateritius (already exists)
# [442/1161] Saved Cantharellus_lateritius
# ⏭️  Skipping Suillus_salmonicolor (already exists)
# [443/1161] Saved Suillus_salmonicolor
# ⏭️  Skipping Leccinum_aurantiacum (already exists)
# [444/1161] Saved Leccinum_aurantiacum
# ⏭️  Skipping Cortinarius_hemitrichus (already exists)
# [445/1161] Saved Cortinarius_hemitrichus
# ⏭️  Skipping Panaeolus_fimicola (already exists)
# [446/1161] Saved Panaeolus_fimicola
# ⏭️  Skipping Sarcoscypha_dudleyi (already exists)
# [447/1161] Saved Sarcoscypha_dudleyi
# [448/1161] Saved Paxillus_filamentosus
# [449/1161] Saved Agaricus_phaeolepidotus
# [450/1161] Saved Agaricus_benesii
# ⏭️  Skipping Mycena_flavescens (already exists)
# [451/1161] Saved Mycena_flavescens
# ⏭️  Skipping Tulosesus_impatiens (already exists)
# [452/1161] Saved Tulosesus_impatiens
# ⏭️  Skipping Tricholoma_argyraceum (already exists)
# [453/1161] Saved Tricholoma_argyraceum
# ⏭️  Skipping Gymnopilus_aeruginosus (already exists)
# [454/1161] Saved Gymnopilus_aeruginosus
# [455/1161] Saved Gymnopilus_chrysotrichoides
# [456/1161] Saved Gymnopilus_chrysimyces
# [457/1161] Saved Gymnopilus_communis
# [458/1161] Saved Gymnopilus_chrysites
# [459/1161] Saved Gymnopilus_chrysopellus
# [460/1161] Saved Gymnopilus_corsicus
# [461/1161] Saved Gymnopilus_condensus
# [462/1161] Saved Gymnopilus_croceoluteus
# [463/1161] Saved Gymnopilus_corticophilus
# [464/1161] Saved Gymnopilus_crassitunicatus
# [465/1161] Saved Gymnopilus_crocophyllus
# [466/1161] Saved Gymnopilus_crocias
# [467/1161] Saved Gymnopilus_decoratus
# [468/1161] Saved Gymnopilus_cyanopalmicola
# [469/1161] Saved Gymnopilus_dulongjiangensis
# [470/1161] Saved Gymnopilus_depressus
# [471/1161] Saved Gymnopilus_echinulisporus
# [472/1161] Saved Gymnopilus_epileatum
# [473/1161] Saved Gymnopilus_eucalyptorum
# [474/1161] Saved Gymnopilus_edulis
# [475/1161] Saved Gymnopilus_elongatipes
# [476/1161] Saved Gymnopilus_excentriciformis
# [477/1161] Saved Gymnopilus_ferruginosus
# [478/1161] Saved Gymnopilus_fagicola
# [479/1161] Saved Gymnopilus_farinaceus
# [480/1161] Saved Gymnopilus_flavidellus
# [481/1161] Saved Gymnopilus_fibrillosipes
# [482/1161] Saved Gymnopilus_flavipunctatus
# [483/1161] Saved Gymnopilus_filiceus
# [484/1161] Saved Gymnopilus_flavifolius
# [485/1161] Saved Gymnopilus_fulgens
# [486/1161] Saved Gymnopilus_fulvicolor
# [487/1161] Saved Gymnopilus_fuscosquamulosus
# [488/1161] Saved Gymnopilus_fulviconicus
# [489/1161] Saved Gymnopilus_fulvellus
# [490/1161] Saved Gymnopilus_galerinopsis
# [491/1161] Saved Gymnopilus_fulvosquamulosus
# [492/1161] Saved Gymnopilus_giganteus
# [493/1161] Saved Gymnopilus_helvoliceps
# [494/1161] Saved Gymnopilus_granulosus
# [495/1161] Saved Gymnopilus_hainanensis
# [496/1161] Saved Gymnopilus_hemipenetrans
# [497/1161] Saved Gymnopilus_hispidellus
# [498/1161] Saved Gymnopilus_hillii
# [499/1161] Saved Gymnopilus_hybridus
# [500/1161] Saved Gymnopilus_humicola
# [501/1161] Saved Gymnopilus_igniculus
# [502/1161] Saved Gymnopilus_jalapensis
# [503/1161] Saved Gymnopilus_imperialis
# [504/1161] Saved Gymnopilus_hypholomoides
# [505/1161] Saved Gymnopilus_intermedius
# [506/1161] Saved Gymnopilus_konkinyerius
# [507/1161] Saved Gymnopilus_janthinosarx
# [508/1161] Saved Gymnopilus_laricicola
# [509/1161] Saved Gymnopilus_lepidotus
# [510/1161] Saved Gymnopilus_lacticolor
# [511/1161] Saved Gymnopilus_levis
# [512/1161] Saved Gymnopilus_latus
# [513/1161] Saved Gymnopilus_luteocarneus
# [514/1161] Saved Gymnopilus_longisporus
# [515/1161] Saved Gymnopilus_longipes
# [516/1161] Saved Gymnopilus_lutescens
# [517/1161] Saved Gymnopilus_luteus
# [518/1161] Saved Gymnopilus_ludovicianus
# ⏭️  Skipping Gymnopilus_luteoviridis (already exists)
# [519/1161] Saved Gymnopilus_luteoviridis
# [520/1161] Saved Gymnopilus_macrocheilocystidiatus
# ⏭️  Skipping Gymnopilus_luteofolius (already exists)
# [521/1161] Saved Gymnopilus_luteofolius
# [522/1161] Saved Gymnopilus_magnus
# [523/1161] Saved Gymnopilus_marasmioides
# [524/1161] Saved Gymnopilus_magnificus
# ⏭️  Skipping Gymnopilus_maritimus (already exists)
# [525/1161] Saved Gymnopilus_maritimus
# [526/1161] Saved Gymnopilus_marginatus
# [527/1161] Saved Gymnopilus_medius
# [528/1161] Saved Gymnopilus_megasporus
# [529/1161] Saved Gymnopilus_melleus
# [530/1161] Saved Gymnopilus_microloxus
# [531/1161] Saved Gymnopilus_mesosporus
# [532/1161] Saved Gymnopilus_micromegas
# [533/1161] Saved Gymnopilus_microsporus
# [534/1161] Saved Gymnopilus_mitis
# [535/1161] Saved Gymnopilus_minutosporus
# [536/1161] Saved Gymnopilus_mullaunius
# [537/1161] Saved Gymnopilus_moabus
# [538/1161] Saved Gymnopilus_naucorioides
# [539/1161] Saved Gymnopilus_multifolius
# [540/1161] Saved Gymnopilus_nashii
# [541/1161] Saved Gymnopilus_nitens
# [542/1161] Saved Gymnopilus_njalaensis
# [543/1161] Saved Gymnopilus_nevadensis
# [544/1161] Saved Gymnopilus_norfolkensis
# [545/1161] Saved Gymnopilus_noviholocirrhus
# [546/1161] Saved Gymnopilus_ochraceus
# [547/1161] Saved Gymnopilus_olivaceobrunneus
# [548/1161] Saved Gymnopilus_novoguineensis
# [549/1161] Saved Gymnopilus_obscurus
# [550/1161] Saved Gymnopilus_oregonensis
# [551/1161] Saved Gymnopilus_odini
# [552/1161] Saved Gymnopilus_omphalina
# ⏭️  Skipping Plectania_nannfeldtii (already exists)
# [553/1161] Saved Plectania_nannfeldtii
# [554/1161] Saved Pluteus_nevadensis
# ⏭️  Skipping Psathyrella_ammophila (already exists)
# [555/1161] Saved Psathyrella_ammophila
# [556/1161] Saved Pseudocolus_fusiformis
# ⏭️  Skipping Psilocybe_atlantis (already exists)
# [557/1161] Saved Psilocybe_atlantis
# ⏭️  Skipping Psilocybe_aucklandiae (already exists)
# [558/1161] Saved Psilocybe_aucklandiae
# ⏭️  Skipping Psilocybe_caerulescens (already exists)
# [559/1161] Saved Psilocybe_caerulescens
# ⏭️  Skipping Psilocybe_caerulipes (already exists)
# [560/1161] Saved Psilocybe_caerulipes
# ⏭️  Skipping Psilocybe_cyanofibrillosa (already exists)
# [561/1161] Saved Psilocybe_cyanofibrillosa
# ⏭️  Skipping Psilocybe_fimetaria (already exists)
# [562/1161] Saved Psilocybe_fimetaria
# [563/1161] Saved Psilocybe_graveolens
# ⏭️  Skipping Psilocybe_guilartensis (already exists)
# [564/1161] Saved Psilocybe_guilartensis
# ⏭️  Skipping Psilocybe_hoogshagenii (already exists)
# [565/1161] Saved Psilocybe_hoogshagenii
# [566/1161] Saved Psilocybe_hispanica
# ⏭️  Skipping Psilocybe_mescaleroensis (already exists)
# [567/1161] Saved Psilocybe_mescaleroensis
# ⏭️  Skipping Psilocybe_naematoliformis (already exists)
# [568/1161] Saved Psilocybe_naematoliformis
# ⏭️  Skipping Psilocybe_ovoideocystidiata (already exists)
# [569/1161] Saved Psilocybe_ovoideocystidiata
# ⏭️  Skipping Psilocybe_pelliculosa (already exists)
# [570/1161] Saved Psilocybe_pelliculosa
# [571/1161] Saved Psilocybe_plutonia
# [572/1161] Saved Psilocybe_samuiensis
# ⏭️  Skipping Psilocybe_quebecensis (already exists)
# [573/1161] Saved Psilocybe_quebecensis
# ⏭️  Skipping Psilocybe_stuntzii (already exists)
# [574/1161] Saved Psilocybe_stuntzii
# ⏭️  Skipping Psilocybe_strictipes (already exists)
# [575/1161] Saved Psilocybe_strictipes
# ⏭️  Skipping Psilocybe_subcaerulipes (already exists)
# [576/1161] Saved Psilocybe_subcaerulipes
# [577/1161] Saved Psilocybe_villarrealiae
# [578/1161] Saved Psilocybe_weilii
# ⏭️  Skipping Psilocybe_yungensis (already exists)
# [579/1161] Saved Psilocybe_yungensis
# [580/1161] Saved Psilocybe_weraroa
# ⏭️  Skipping Psilocybe_zapotecorum (already exists)
# [581/1161] Saved Psilocybe_zapotecorum
# [582/1161] Saved Ramariopsis_kunzei
# [583/1161] Saved Gymnopilus_pacificus
# [584/1161] Saved Gymnopilus_oxylepis
# [585/1161] Saved Gymnopilus_palmicola
# [586/1161] Saved Gymnopilus_pallidus
# [587/1161] Saved Gymnopilus_panelloides
# [588/1161] Saved Gymnopilus_panurensis
# [589/1161] Saved Gymnopilus_parvulus
# [590/1161] Saved Gymnopilus_parvisquamulosus
# [591/1161] Saved Gymnopilus_parrumbalus
# [592/1161] Saved Gymnopilus_pholiotoides
# [593/1161] Saved Gymnopilus_permollis
# [594/1161] Saved Gymnopilus_patriae
# [595/1161] Saved Gymnopilus_perisporius
# [596/1161] Saved Gymnopilus_peliolepis
# [597/1161] Saved Gymnopilus_pleurocystidiatus
# [598/1161] Saved Gymnopilus_picreus
# [599/1161] Saved Gymnopilus_praefloccosus
# [600/1161] Saved Gymnopilus_piceinus
# [601/1161] Saved Gymnopilus_praecox
# [602/1161] Saved Gymnopilus_praelaeticolor
# [603/1161] Saved Gymnopilus_pulchrifolius
# [604/1161] Saved Gymnopilus_primulinus
# [605/1161] Saved Gymnopilus_pratensis
# [606/1161] Saved Gymnopilus_psamminus
# [607/1161] Saved Gymnopilus_pseudocamerinus
# ⏭️  Skipping Gymnopilus_purpuratus (already exists)
# [608/1161] Saved Gymnopilus_purpuratus
# [609/1161] Saved Gymnopilus_rufescens
# [610/1161] Saved Gymnopilus_pusillus
# [611/1161] Saved Gymnopilus_radicicola
# [612/1161] Saved Gymnopilus_rigidus
# [613/1161] Saved Gymnopilus_rufobrunneus
# [614/1161] Saved Gymnopilus_robustus
# [615/1161] Saved Gymnopilus_rufosquamulosus
# [616/1161] Saved Gymnopilus_rugulosus
# [617/1161] Saved Gymnopilus_russipes
# [618/1161] Saved Gymnopilus_rufopunctatus
# [619/1161] Saved Gymnopilus_sordidostipes
# [620/1161] Saved Gymnopilus_satur
# [621/1161] Saved Gymnopilus_spadiceus
# ⏭️  Skipping Gymnopilus_sapineus (already exists)
# [622/1161] Saved Gymnopilus_sapineus
# [623/1161] Saved Gymnopilus_squalidus
# [624/1161] Saved Gymnopilus_sphagnicola
# [625/1161] Saved Gymnopilus_spinulifer
# [626/1161] Saved Gymnopilus_squamulosus
# [627/1161] Saved Gymnopilus_subbellulus
# [628/1161] Saved Gymnopilus_subdryophilus
# [629/1161] Saved Gymnopilus_subcarbonarius
# [630/1161] Saved Gymnopilus_subearlei
# [631/1161] Saved Gymnopilus_suberis
# [632/1161] Saved Gymnopilus_stabilis
# [633/1161] Saved Gymnopilus_subfulgens
# [634/1161] Saved Gymnopilus_subfulvus
# [635/1161] Saved Gymnopilus_subgeminellus
# [636/1161] Saved Gymnopilus_subsapineus
# [637/1161] Saved Gymnopilus_subpenetrans
# [638/1161] Saved Gymnopilus_subtropicus
# [639/1161] Saved Gymnopilus_subpurpuratus
# [640/1161] Saved Gymnopilus_subrufobrunneus
# [641/1161] Saved Gymnopilus_subsphaerosporus
# [642/1161] Saved Gymnopilus_tasmanicus
# [643/1161] Saved Gymnopilus_tenuis
# [644/1161] Saved Gymnopilus_subviridis
# [645/1161] Saved Gymnopilus_terrestris
# [646/1161] Saved Gymnopilus_testaceus
# [647/1161] Saved Gymnopilus_thiersii
# [648/1161] Saved Gymnopilus_terricola
# [649/1161] Saved Gymnopilus_trailii
# [650/1161] Saved Gymnopilus_tomentulosus
# [651/1161] Saved Gymnopilus_tonkinensis
# [652/1161] Saved Gymnopilus_tuxtlensis
# [653/1161] Saved Gymnopilus_tropicus
# [654/1161] Saved Gymnopilus_tyallus
# ⏭️  Skipping Gymnopilus_validipes (already exists)
# [655/1161] Saved Gymnopilus_validipes
# [656/1161] Saved Gymnopilus_velatus
# [657/1161] Saved Gymnopilus_velutinus
# [658/1161] Saved Gymnopilus_unicolor
# [659/1161] Saved Gymnopilus_ventricosus
# [660/1161] Saved Gymnopilus_viridans
# [661/1161] Saved Gymnopilus_vialis
# [662/1161] Saved Gymnopilus_weberi
# [663/1161] Saved Gymnopilus_yangshanensis
# [664/1161] Saved Gymnopilus_viscidissimus
# [665/1161] Saved Gymnopilus_viscidus
# [666/1161] Saved Gymnopilus_zempoalensis
# [667/1161] Saved Gymnopilus_zenkeri
# [668/1161] Saved Porpolomopsis_lewelliniae
# [669/1161] Saved Mycena_fuscoaurantiaca
# ⏭️  Skipping Hebeloma_aminophilum (already exists)
# [670/1161] Saved Hebeloma_aminophilum
# [671/1161] Saved Hericium_abietis
# ⏭️  Skipping Mycena_adscendens (already exists)
# [672/1161] Saved Mycena_adscendens
# ⏭️  Skipping Mycena_cyanorrhiza (already exists)
# [673/1161] Saved Mycena_cyanorrhiza
# ⏭️  Skipping Mycena_urania (already exists)
# [674/1161] Saved Mycena_urania
# [675/1161] Saved Hydnellum_ferrugineum
# [676/1161] Saved Hydnellum_concrescens
# [677/1161] Saved Hygrocybe_aurantipes
# [678/1161] Saved Gymnopilus_ombrophilus
# [679/1161] Saved Gymnopilus_ornatulus
# [680/1161] Saved Staheliomyces
# ⏭️  Skipping Stropharia_ambigua (already exists)
# [681/1161] Saved Stropharia_ambigua
# ⏭️  Skipping Cortinarius_gentilis (already exists)
# [682/1161] Saved Cortinarius_gentilis
# [683/1161] Saved Artomyces_pyxidatus
# ⏭️  Skipping Sarcoscypha_austriaca (already exists)
# [684/1161] Saved Sarcoscypha_austriaca
# ⏭️  Skipping Suillus_lakei (already exists)
# [685/1161] Saved Suillus_lakei
# ⏭️  Skipping Leccinellum_crocipodium (already exists)
# [686/1161] Saved Leccinellum_crocipodium
# ⏭️  Skipping Cantharellus_amethysteus (already exists)
# [687/1161] Saved Cantharellus_amethysteus
# [688/1161] Saved Meripilus_giganteus
# [689/1161] Saved Turbinellus_floccosus
# [690/1161] Saved Amanita_nivalis
# [691/1161] Saved Pseudoclitocybe_cyathiformis
# [692/1161] Saved Entoloma_hochstetteri
# [693/1161] Saved Agaricus_langei
# [694/1161] Saved Discina_gigas
# [695/1161] Saved Auriscalpium_vulgare
# [696/1161] Saved Cystoderma_carcharias
# ⏭️  Skipping Tricholoma_columbetta (already exists)
# [697/1161] Saved Tricholoma_columbetta
# [698/1161] Saved Lepiota_castanea
# [699/1161] Saved Russula_albidula
# [700/1161] Saved Russula_subnigricans
# [701/1161] Saved Entoloma_murrayi
# [702/1161] Saved Gastropila_fumosa
# ⏭️  Skipping Agaricus_cupreobrunneus (already exists)
# [703/1161] Saved Agaricus_cupreobrunneus
# ⏭️  Skipping Agaricus_lilaceps (already exists)
# [704/1161] Saved Agaricus_lilaceps
# [705/1161] Saved Agaricus_excellens
# ⏭️  Skipping Agaricus_pattersoniae (already exists)
# [706/1161] Saved Agaricus_pattersoniae
# ⏭️  Skipping Agaricus_hondensis (already exists)
# [707/1161] Saved Agaricus_hondensis
# ⏭️  Skipping Agaricus_dulcidulus (already exists)
# [708/1161] Saved Agaricus_dulcidulus
# ⏭️  Skipping Agaricus_subrutilescens (already exists)
# [709/1161] Saved Agaricus_subrutilescens
# ⏭️  Skipping Amanita_aestivalis (already exists)
# [710/1161] Saved Amanita_aestivalis
# ⏭️  Skipping Amanita_aprica (already exists)
# [711/1161] Saved Amanita_aprica
# ⏭️  Skipping Amanita_elliptosperma (already exists)
# [712/1161] Saved Amanita_elliptosperma
# ⏭️  Skipping Amanita_flavella (already exists)
# [713/1161] Saved Amanita_flavella
# ⏭️  Skipping Amanita_atkinsoniana (already exists)
# [714/1161] Saved Amanita_atkinsoniana
# ⏭️  Skipping Amanita_australis (already exists)
# [715/1161] Saved Amanita_australis
# ⏭️  Skipping Amanita_franchetii (already exists)
# [716/1161] Saved Amanita_franchetii
# [717/1161] Saved Amanita_virosiformis
# ⏭️  Skipping Amanita_volvata (already exists)
# [718/1161] Saved Amanita_volvata
# ⏭️  Skipping Amanita_nehuta (already exists)
# [719/1161] Saved Amanita_nehuta
# ⏭️  Skipping Amanita_magnivelaris (already exists)
# [720/1161] Saved Amanita_magnivelaris
# ⏭️  Skipping Amanita_ravenelii (already exists)
# [721/1161] Saved Amanita_ravenelii
# ⏭️  Skipping Amanita_nothofagi (already exists)
# [722/1161] Saved Amanita_nothofagi
# [723/1161] Saved Amanita_subvaginata
# ⏭️  Skipping Amanita_rubrovolvata (already exists)
# [724/1161] Saved Amanita_rubrovolvata
# [725/1161] Saved Amanita_sphaerobulbosa
# [726/1161] Saved Aseroe_coccinea
# [727/1161] Saved Astraeus_asiaticus
# [728/1161] Saved Astraeus_pteridis
# [729/1161] Saved Astraeus_koreanus
# ⏭️  Skipping Boletus_auripes (already exists)
# [730/1161] Saved Boletus_auripes
# [731/1161] Saved Crucibulum_(fungus)
# [732/1161] Saved Bridgeoporus
# [733/1161] Saved Calvatia_sculpta
# ⏭️  Skipping Cantharellus_formosus (already exists)
# [734/1161] Saved Cantharellus_formosus
# ⏭️  Skipping Cantharellus_cinnabarinus (already exists)
# [735/1161] Saved Cantharellus_cinnabarinus
# ⏭️  Skipping Cantharellus_persicinus (already exists)
# [736/1161] Saved Cantharellus_persicinus
# [737/1161] Saved Catathelasma_evanescens
# [738/1161] Saved Clathrus_baumii
# [739/1161] Saved Clathrus_bicolumnatus
# [740/1161] Saved Clathrus_crispatus
# [741/1161] Saved Clathrus_chrysomycelinus
# [742/1161] Saved Clathrus_hainanensis
# [743/1161] Saved Clathrus_kusanoi
# [744/1161] Saved Clathrus_cristatus
# [745/1161] Saved Clathrus_delicatus
# [746/1161] Saved Clathrus_treubii
# [747/1161] Saved Clathrus_mauritianus
# [748/1161] Saved Clathrus_xiningensis
# [749/1161] Saved Climacodon_septentrionalis
# ⏭️  Skipping Collybia_tuberosa (already exists)
# [750/1161] Saved Collybia_tuberosa
# ⏭️  Skipping Collybia_cookei (already exists)
# [751/1161] Saved Collybia_cookei
# [752/1161] Saved Conocybe_kuehneriana
# ⏭️  Skipping Conocybe_rickenii (already exists)
# [753/1161] Saved Conocybe_rickenii
# ⏭️  Skipping Coprinopsis_cinerea (already exists)
# [754/1161] Saved Coprinopsis_cinerea
# ⏭️  Skipping Cortinarius_flexipes (already exists)
# [755/1161] Saved Cortinarius_flexipes
# ⏭️  Skipping Phlegmacium_ponderosum (already exists)
# [756/1161] Saved Phlegmacium_ponderosum
# ⏭️  Skipping Cortinarius_rotundisporus (already exists)
# [757/1161] Saved Cortinarius_rotundisporus
# ⏭️  Skipping Ganoderma_curtisii (already exists)
# [758/1161] Saved Ganoderma_curtisii
# ⏭️  Skipping Ganoderma_tsugae (already exists)
# [759/1161] Saved Ganoderma_tsugae
# ⏭️  Skipping Ganoderma_multipileum (already exists)
# [760/1161] Saved Ganoderma_multipileum
# [761/1161] Saved Geastrum_australe
# ⏭️  Skipping Cyptotrama_asprata (already exists)
# [762/1161] Saved Cyptotrama_asprata
# ⏭️  Skipping Cystolepiota_bucknallii (already exists)
# [763/1161] Saved Cystolepiota_bucknallii
# [764/1161] Saved Geastrum_corollinum
# [765/1161] Saved Geastrum_coronatum
# [766/1161] Saved Gymnopilus_crociphyllus
# ⏭️  Skipping Xerula_megalospora (already exists)
# [767/1161] Saved Xerula_megalospora
# [768/1161] Saved Gymnopilus_decipiens
# ⏭️  Skipping Mycena_vinacea (already exists)
# [769/1161] Saved Mycena_vinacea
# [770/1161] Saved Gymnopilus_dilepis
# ⏭️  Skipping Mycena_maculata (already exists)
# [771/1161] Saved Mycena_maculata
# [772/1161] Saved Entoloma_abortivum
# [773/1161] Saved Gymnopilus_flavus
# ⏭️  Skipping Mycena_crocea (already exists)
# [774/1161] Saved Mycena_crocea
# [775/1161] Saved Tricholoma_pessundatum
# ⏭️  Skipping Mycena_crocata (already exists)
# [776/1161] Saved Mycena_crocata
# [777/1161] Saved Geastrum_campestre
# [778/1161] Saved Geastrum_berkeleyi
# [779/1161] Saved Geastrum_entomophilum
# [780/1161] Saved Geastrum_elegans
# [781/1161] Saved Geastrum_welwitschii
# [782/1161] Saved Geastrum_jurei
# [783/1161] Saved Geastrum_leptospermum
# [784/1161] Saved Mycena_fonticola
# [785/1161] Saved Gymnopilus_abramsii
# [786/1161] Saved Gymnopilus_acystidiatus
# ...
# [904/1161] Saved Lepista_glaucocana
# [905/1161] Saved Sarcodon_squamosus
# ⏭️  Skipping Mycena_aetites (already exists)
# [906/1161] Saved Mycena_aetites
# [907/1161] Saved Helvella_corium
# ⏭️  Skipping Leucopaxillus_gentianeus (already exists)
# [908/1161] Saved Leucopaxillus_gentianeus
# [909/1161] Saved Otidea_leporina
# [910/1161] Saved Inocybe_godeyi
# ⏭️  Skipping Inocybe_praetervisa (already exists)
# [911/1161] Saved Inocybe_praetervisa
# [912/1161] Saved Lepiota_ignivolvata
# ⏭️  Skipping Atheniella_flavoalba (already exists)
# [913/1161] Saved Atheniella_flavoalba
# [914/1161] Saved Spathularia_flavida
# [915/1161] Saved Hydnellum_caeruleum
# [916/1161] Saved Hydnellum_aurantiacum
# ⏭️  Skipping Collybia_cirrhata (already exists)
# [917/1161] Saved Collybia_cirrhata
# ⏭️  Skipping Limacella_illinita (already exists)
# [918/1161] Saved Limacella_illinita
# ⏭️  Skipping Cystodermella_cinnabarina (already exists)
# [919/1161] Saved Cystodermella_cinnabarina
# [920/1161] Saved Hygrophorus_camarophyllus
# [921/1161] Saved Caloscypha
# ⏭️  Skipping Inocybe_corydalina_var._corydalina (already exists)
# [922/1161] Saved Inocybe_corydalina_var._corydalina
# [923/1161] Saved Ischnoderma_resinosum
# [924/1161] Saved Tricholoma_acerbum
# [925/1161] Saved Tuber_macrosporum
# ⏭️  Skipping Volvariella_surrecta (already exists)
# [926/1161] Saved Volvariella_surrecta
# ⏭️  Skipping Agaricus_brunneofibrillosus (already exists)
# [927/1161] Saved Agaricus_brunneofibrillosus
# ⏭️  Skipping Amanita_frostiana (already exists)
# [928/1161] Saved Amanita_frostiana
# ⏭️  Skipping Amanita_albocreata (already exists)
# [929/1161] Saved Amanita_albocreata
# ⏭️  Skipping Amanita_bisporigera (already exists)
# [930/1161] Saved Amanita_bisporigera
# ⏭️  Skipping Amanita_parcivolvata (already exists)
# [931/1161] Saved Amanita_parcivolvata
# ⏭️  Skipping Boletus_subluridellus (already exists)
# [932/1161] Saved Boletus_subluridellus
# ⏭️  Skipping Boletus_sensibilis (already exists)
# [933/1161] Saved Boletus_sensibilis
# ⏭️  Skipping Boletus_rubroflammeus (already exists)
# [934/1161] Saved Boletus_rubroflammeus
# ⏭️  Skipping Boletus_subvelutipes (already exists)
# [935/1161] Saved Boletus_subvelutipes
# ⏭️  Skipping Amanita_daucipes (already exists)
# [936/1161] Saved Amanita_daucipes
# [937/1161] Saved Amanita_onusta
# ⏭️  Skipping Amanita_velosa (already exists)
# [938/1161] Saved Amanita_velosa
# [939/1161] Saved Laccocephalum_basilapidoides
# ⏭️  Skipping Lactarius_affinis (already exists)
# [940/1161] Saved Lactarius_affinis
# ⏭️  Skipping Lactarius_fallax (already exists)
# [941/1161] Saved Lactarius_fallax
# ⏭️  Skipping Lactarius_fumosus (already exists)
# [942/1161] Saved Lactarius_fumosus
# ⏭️  Skipping Lactarius_rubrilacteus (already exists)
# [943/1161] Saved Lactarius_rubrilacteus
# ⏭️  Skipping Lactarius_subflammeus (already exists)
# [944/1161] Saved Lactarius_subflammeus
# [945/1161] Saved Leotia_atrovirens
# [946/1161] Saved Leotia_viscosa
# ⏭️  Skipping Leucocoprinus_brebissonii (already exists)
# [947/1161] Saved Leucocoprinus_brebissonii
# ⏭️  Skipping Leucopaxillus_albissimus (already exists)
# [948/1161] Saved Leucopaxillus_albissimus
# [949/1161] Saved Peziza_arvernensis
# [950/1161] Saved Lycoperdon_pulcherrimum
# [951/1161] Saved Lycoperdon_molle
# ⏭️  Skipping Lysurus_periphragmoides (already exists)
# [952/1161] Saved Lysurus_periphragmoides
# ⏭️  Skipping Macrocybe_titans (already exists)
# [953/1161] Saved Macrocybe_titans
# ⏭️  Skipping Melanoleuca_melaleuca (already exists)
# [954/1161] Saved Melanoleuca_melaleuca
# ⏭️  Skipping Mycena_arcangeliana (already exists)
# [955/1161] Saved Mycena_arcangeliana
# ⏭️  Skipping Mycena_aurantiomarginata (already exists)
# [956/1161] Saved Mycena_aurantiomarginata
# ⏭️  Skipping Marasmius_elegans (already exists)
# [957/1161] Saved Marasmius_elegans
# [958/1161] Saved Mycena_clariviolacea
# ⏭️  Skipping Mycena_cinerella (already exists)
# [959/1161] Saved Mycena_cinerella
# ⏭️  Skipping Mycena_kuurkacea (already exists)
# [960/1161] Saved Mycena_kuurkacea
# [961/1161] Saved Mycena_multiplicata
# ⏭️  Skipping Mycena_leaiana (already exists)
# [962/1161] Saved Mycena_leaiana
# [963/1161] Saved Mycena_nidificata
# ⏭️  Skipping Mycena_nargan (already exists)
# [964/1161] Saved Mycena_nargan
# ⏭️  Skipping Mycena_olida (already exists)
# [965/1161] Saved Mycena_olida
# ⏭️  Skipping Mycena_stylobates (already exists)
# [966/1161] Saved Mycena_stylobates
# ⏭️  Skipping Mycena_overholtsii (already exists)
# [967/1161] Saved Mycena_overholtsii
# ⏭️  Skipping Omphalotus_olivascens (already exists)
# [968/1161] Saved Omphalotus_olivascens
# ⏭️  Skipping Panaeolina_castaneifolia (already exists)
# [969/1161] Saved Panaeolina_castaneifolia
# ⏭️  Skipping Panaeolus_antillarum (already exists)
# [970/1161] Saved Panaeolus_antillarum
# ⏭️  Skipping Omphalotus_japonicus (already exists)
# [971/1161] Saved Omphalotus_japonicus
# ⏭️  Skipping Omphalotus_illudens (already exists)
# [972/1161] Saved Omphalotus_illudens
# [973/1161] Saved Panaeolus_africanus
# ⏭️  Skipping Panaeolus_cambodginiensis (already exists)
# [974/1161] Saved Panaeolus_cambodginiensis
# [975/1161] Saved Panaeolus_bisporus
# ⏭️  Skipping Panaeolus_olivaceus (already exists)
# [976/1161] Saved Panaeolus_olivaceus
# ⏭️  Skipping Panaeolus_papilionaceus_var._parvisporus (already exists)
# [977/1161] Saved Panaeolus_papilionaceus_var._parvisporus
# ⏭️  Skipping Panaeolus_tropicalis (already exists)
# [978/1161] Saved Panaeolus_tropicalis
# [979/1161] Saved Panaeolus_semiovatus_var._phalaenarum
# ⏭️  Skipping Phallus_calongei (already exists)
# [980/1161] Saved Phallus_calongei
# [981/1161] Saved Phallus_pygmaeus
# [982/1161] Saved Phallus_ravenelii
# ⏭️  Skipping Phlebopus_marginatus (already exists)
# [983/1161] Saved Phlebopus_marginatus
# [984/1161] Saved Agaricus_bresadolanus
# [985/1161] Saved Amauroderma_rude
# [986/1161] Saved Bondarzewia_berkeleyi
# [987/1161] Saved Suillus_neoalbidipes
# [988/1161] Saved Suillus_glandulosipes
# [989/1161] Saved Suillus_pungens
# [990/1161] Saved Suillus_pseudobrevipes
# [991/1161] Saved Suillus_quiescens
# ⏭️  Skipping Tectella_patellaris (already exists)
# [992/1161] Saved Tectella_patellaris
# ⏭️  Skipping Tricholoma_ustaloides (already exists)
# [993/1161] Saved Tricholoma_ustaloides
# [994/1161] Saved Tuber_gibbosum
# [995/1161] Saved Tuber_oregonense
# ⏭️  Skipping Tylopilus_atronicotianus (already exists)
# [996/1161] Saved Tylopilus_atronicotianus
# ⏭️  Skipping Tylopilus_plumbeoviolaceus (already exists)
# [997/1161] Saved Tylopilus_plumbeoviolaceus
# [998/1161] Saved Typhula_quisquiliaris
# [999/1161] Saved Mycena_intersecta
# ⏭️  Skipping Mycena_vitilis (already exists)
# [1000/1161] Saved Mycena_vitilis
# ⏭️  Skipping Psilocybe_meridionalis (already exists)
# [1001/1161] Saved Psilocybe_meridionalis
# [1002/1161] Saved Gymnopilus_purpureonitens
# ⏭️  Skipping Boletus_manicus (already exists)
# [1003/1161] Saved Boletus_manicus
# [1004/1161] Saved Tricholoma_cingulatum
# [1005/1161] Saved Gloiodon_strigosus
# [1006/1161] Saved Hydnellum_auratile
# ⏭️  Skipping Cantharellus_subpruinosus (already exists)
# [1007/1161] Saved Cantharellus_subpruinosus
# [1008/1161] Saved Limacella_guttata
# ⏭️  Skipping Ganoderma_sichuanense (already exists)
# [1009/1161] Saved Ganoderma_sichuanense
# [1010/1161] Saved Phellodon_confluens
# [1011/1161] Saved Chrysomphalina_chrysophylla
# [1012/1161] Saved Melanoleuca_cognata
# ⏭️  Skipping Humidicutis_marginata (already exists)
# [1013/1161] Saved Humidicutis_marginata
# [1014/1161] Saved Hydnellum_spongiosipes
# [1015/1161] Saved Hydnum_ellipsosporum
# [1016/1161] Saved Hydnum_umbilicatum
# ⏭️  Skipping Panaeolus_cinctulus (already exists)
# [1017/1161] Saved Panaeolus_cinctulus
# [1018/1161] Saved Hydnellum_compactum
# [1019/1161] Saved Lepista_panaeolus
# ⏭️  Skipping Leucopholiota_decorosa (already exists)
# [1020/1161] Saved Leucopholiota_decorosa
# ⏭️  Skipping Macrocybe_spectabilis (already exists)
# [1021/1161] Saved Macrocybe_spectabilis
# ⏭️  Skipping Mycena_cystidiosa (already exists)
# [1022/1161] Saved Mycena_cystidiosa
# ⏭️  Skipping Paxillus_vernalis (already exists)
# [1023/1161] Saved Paxillus_vernalis
# [1024/1161] Saved Phellodon_melaleucus
# ⏭️  Skipping Psilocybe_subaeruginascens (already exists)
# [1025/1161] Saved Psilocybe_subaeruginascens
# [1026/1161] Saved Hydnellum_mirabile
# ⏭️  Skipping Roridomyces_austrororidus (already exists)
# [1027/1161] Saved Roridomyces_austrororidus
# ⏭️  Skipping Roridomyces_roridus (already exists)
# [1028/1161] Saved Roridomyces_roridus
# [1029/1161] Saved Bjerkandera_fumosa
# [1030/1161] Saved Scutiger_pes-caprae
# [1031/1161] Saved Hydnellum_scrobiculatum
# [1032/1161] Saved Pholiota_adiposa
# [1033/1161] Saved Hydnellum_gracilipes
# [1034/1161] Saved Sarcodon_leucopus
# [1035/1161] Saved Lingzhi_(mushroom)
# [1036/1161] Saved Hericium_cirrhatum
# [1037/1161] Saved Cuphophyllus_virgineus
# ⏭️  Skipping Lactifluus_volemus (already exists)
# [1038/1161] Saved Lactifluus_volemus
# ⏭️  Skipping Rubroboletus_dupainii (already exists)
# [1039/1161] Saved Rubroboletus_dupainii
# [1040/1161] Saved Agaricus_abruptibulbus
# [1041/1161] Saved Agaricus_braendlei
# [1042/1161] Saved Agaricus_julius
# [1043/1161] Saved Aureoboletus_mirabilis
# [1044/1161] Saved Auricularia_heimuer
# ⏭️  Skipping Britzelmayria_multipedata (already exists)
# [1045/1161] Saved Britzelmayria_multipedata
# [1046/1161] Saved Exsudoporus_frostii
# [1047/1161] Saved Exsudoporus_floridanus
# [1048/1161] Saved Harrya_chromapes
# ⏭️  Skipping Butyriboletus_regius (already exists)
# [1049/1161] Saved Butyriboletus_regius
# ⏭️  Skipping Rubroboletus_pulcherrimus (already exists)
# [1050/1161] Saved Rubroboletus_pulcherrimus
# [1051/1161] Saved Fomitopsis_betulina
# ⏭️  Skipping Cerioporus_squamosus (already exists)
# [1052/1161] Saved Cerioporus_squamosus
# ⏭️  Skipping Candy_cap (already exists)
# [1053/1161] Saved Candy_cap
# ⏭️  Skipping Collybia_nuda (already exists)
# [1054/1161] Saved Collybia_nuda
# ⏭️  Skipping Lactarius_turpis (already exists)
# [1055/1161] Saved Lactarius_turpis
# ⏭️  Skipping Hygrocybe_coccinea (already exists)
# [1056/1161] Saved Hygrocybe_coccinea
# ⏭️  Skipping Hygrocybe_punicea (already exists)
# [1057/1161] Saved Hygrocybe_punicea
# ⏭️  Skipping Mycetinis_alliaceus (already exists)
# [1058/1161] Saved Mycetinis_alliaceus
# ⏭️  Skipping Tricholoma_terreum (already exists)
# [1059/1161] Saved Tricholoma_terreum
# ⏭️  Skipping Amanita_pantherina (already exists)
# [1060/1161] Saved Amanita_pantherina
# [1061/1161] Saved Hydnellum_lundellii
# [1062/1161] Saved Hydnellum_versipelle
# ⏭️  Skipping Inosperma_cookei (already exists)
# [1063/1161] Saved Inosperma_cookei
# [1064/1161] Saved Inosperma_erubescens
# [1065/1161] Saved Pseudocraterellus_undulatus
# [1066/1161] Saved Phallus_impudicus
# [1067/1161] Saved Sparassis_crispa
# ⏭️  Skipping Lactarius_deliciosus (already exists)
# [1068/1161] Saved Lactarius_deliciosus
# ⏭️  Skipping Cortinarius_infractus (already exists)
# [1069/1161] Saved Cortinarius_infractus
# [1070/1161] Saved Tricholoma_apium
# ⏭️  Skipping Suillellus_amygdalinus (already exists)
# [1071/1161] Saved Suillellus_amygdalinus
# [1072/1161] Saved Hydnellum_geogenium
# [1073/1161] Saved Gymnopilus_anomalus
# ⏭️  Skipping Hygrocybe_austropratensis (already exists)
# [1074/1161] Saved Hygrocybe_austropratensis
# [1075/1161] Saved Craterellus_cinereus
# ⏭️  Skipping Mycena_atkinsoniana (already exists)
# [1076/1161] Saved Mycena_atkinsoniana
# [1077/1161] Saved Gymnopilus_decurrens
# [1078/1161] Saved Buchwaldoboletus_lignicola
# ⏭️  Skipping Suillus_americanus (already exists)
# [1079/1161] Saved Suillus_americanus
# [1080/1161] Saved Suillus_bresadolae
# [1081/1161] Saved Phellodon_niger
# [1082/1161] Saved Phellodon_secretus
# [1083/1161] Saved Termitomyces_robustus
# [1084/1161] Saved Thelephora_ganbajun
# [1085/1161] Saved Phellodon_tomentosus
# [1086/1161] Saved Psathyrella_spadicea
# [1087/1161] Saved Lepiota_erminea
# [1088/1161] Saved Hydnum_albidum
# [1089/1161] Saved Gymnopilus_alienus
# [1090/1161] Saved Gymnopilus_lateritius
# [1091/1161] Saved Gymnopilus_marticorenai
# [1092/1161] Saved Gymnopilus_foedatus
# [1093/1161] Saved Gymnopilus_karnalensis
# [1094/1161] Saved Gymnopilus_purpureosquamulosus
# [1095/1161] Saved Gymnopilus_parvisporus
# [1096/1161] Saved Gymnopilus_perplexus
# [1097/1161] Saved Gymnopilus_subspectabilis
# [1098/1161] Saved Gymnopilus_subflavidus
# [1099/1161] Saved Gymnopilus_submarasmioides
# [1100/1161] Saved Mycena_lanuginosa
# ⏭️  Skipping Deconica_inquilina (already exists)
# [1101/1161] Saved Deconica_inquilina
# [1102/1161] Saved Butyriboletus_fechtneri
# ⏭️  Skipping Amanita_fuliginea (already exists)
# [1103/1161] Saved Amanita_fuliginea
# [1104/1161] Saved Astraeus_sirindhorniae
# ⏭️  Skipping Neoboletus_luridiformis (already exists)
# [1105/1161] Saved Neoboletus_luridiformis
# ⏭️  Skipping Collybia_personata (already exists)
# [1106/1161] Saved Collybia_personata
# [1107/1161] Saved Laccaria_amethysteo-occidentalis
# [1108/1161] Saved Laetiporus_montanus
# ⏭️  Skipping Neofavolus_alveolaris (already exists)
# [1109/1161] Saved Neofavolus_alveolaris
# [1110/1161] Saved Leccinum_albostipitatum
# [1111/1161] Saved Gymnopilus_earlei
# ⏭️  Skipping Psilocybe_galindoi (already exists)
# [1112/1161] Saved Psilocybe_galindoi
# [1113/1161] Saved Trogia_venenata
# ⏭️  Skipping Tricholoma_vernaticum (already exists)
# [1114/1161] Saved Tricholoma_vernaticum
# [1115/1161] Saved Astraeus_odoratus
# [1116/1161] Saved Flammulina_filiformis
# ⏭️  Skipping Leratiomyces_ceres (already exists)
# [1117/1161] Saved Leratiomyces_ceres
# ⏭️  Skipping Boletus_rubriceps (already exists)
# [1118/1161] Saved Boletus_rubriceps
# [1119/1161] Saved Amanita_excelsa
# ⏭️  Skipping Rubroboletus_lupinus (already exists)
# [1120/1161] Saved Rubroboletus_lupinus
# ⏭️  Skipping Boletus_reticulatus (already exists)
# [1121/1161] Saved Boletus_reticulatus
# ⏭️  Skipping Rubroboletus_satanas (already exists)
# [1122/1161] Saved Rubroboletus_satanas
# [1123/1161] Saved Volvopluteus_gloiocephalus
# [1124/1161] Saved Caloboletus_rubripes
# [1125/1161] Saved Hydnum_vesterholtii
# ⏭️  Skipping Caloboletus_calopus (already exists)
# [1126/1161] Saved Caloboletus_calopus
# ⏭️  Skipping Amanita_persicina (already exists)
# [1127/1161] Saved Amanita_persicina
# ⏭️  Skipping Boletus_curtisii (already exists)
# [1128/1161] Saved Boletus_curtisii
# ⏭️  Skipping Saproamanita_thiersii (already exists)
# [1129/1161] Saved Saproamanita_thiersii
# [1130/1161] Saved Agaricus_amicosus
# [1131/1161] Saved Laccaria_amethystina
# ⏭️  Skipping Coprinopsis_nivea (already exists)
# [1132/1161] Saved Coprinopsis_nivea
# [1133/1161] Saved Amanita_subpallidorosea
# [1134/1161] Saved Hymenopellis_radicata
# [1135/1161] Saved Calocybe_indica
# ⏭️  Skipping Butyriboletus_appendiculatus (already exists)
# [1136/1161] Saved Butyriboletus_appendiculatus
# ⏭️  Skipping Rubroboletus_rhodoxanthus (already exists)
# [1137/1161] Saved Rubroboletus_rhodoxanthus
# ⏭️  Skipping Suillellus_queletii (already exists)
# [1138/1161] Saved Suillellus_queletii
# ⏭️  Skipping Suillus_spraguei (already exists)
# [1139/1161] Saved Suillus_spraguei
# ⏭️  Skipping Baorangia_bicolor (already exists)
# [1140/1161] Saved Baorangia_bicolor
# ⏭️  Skipping Caloboletus_radicans (already exists)
# [1141/1161] Saved Caloboletus_radicans
# ⏭️  Skipping Hydnum_repandum (already exists)
# [1142/1161] Saved Hydnum_repandum
# [1143/1161] Saved Gymnopilus_aurantiobrunneus
# [1144/1161] Saved Handkea_utriformis
# [1145/1161] Saved Auricularia_nigricans
# [1146/1161] Saved Agaricus_crocodilinus
# [1147/1161] Saved Purpureocillium_lilacinum
# [1148/1161] Saved Candolleomyces_candolleanus
# ⏭️  Skipping Hygrocybe_virescens (already exists)
# [1149/1161] Saved Hygrocybe_virescens
# ⏭️  Skipping Hygrophorus_bakerensis (already exists)
# [1150/1161] Saved Hygrophorus_bakerensis
# [1151/1161] Saved Ileodictyon_cibarium
# [1152/1161] Saved Hericium_erinaceus
# [1153/1161] Saved Tremella_mesenterica
# ⏭️  Skipping Boletus_edulis (already exists)
# [1154/1161] Saved Boletus_edulis
# ⏭️  Skipping Mycena_purpureofusca (already exists)
# [1155/1161] Saved Mycena_purpureofusca
# ⏭️  Skipping Inocybe_salicis (already exists)
# [1156/1161] Saved Inocybe_salicis
# [1157/1161] Saved Hydnellum_fuligineoviolaceum
# ⏭️  Skipping Leccinellum_pseudoscabrum (already exists)
# [1158/1161] Saved Leccinellum_pseudoscabrum
# [1159/1161] Saved Rheubarbariboletus_armeniacus
# [1160/1161] Saved Hydnellum_scabrosum
# [1161/1161] Saved Discina_ancilis
# Completed successfully.

# %%
import os
import re
import json

INPUT_DIR = "data/raw_articles_wikitext"
OUTPUT_PATH = "data/parsed_wikitext_data.json"

# --- Regex patterns ---
LINK_PATTERN = re.compile(r"\[\[([^\]|#]+)(?:\|[^\]]+)?\]\]")   # [[Target|Label]] or [[Target]]
CATEGORY_PATTERN = re.compile(r"\[\[Category:([^\]|#]+)")       # [[Category:Something]]
SECTION_PATTERN = re.compile(r"^==+\s*(.*?)\s*==+", re.MULTILINE)

def parse_wikitext(title, text):
    """
    Parse a single wikitext article into structured fields:
    links, categories, section titles, full text.
    """

    # --- Extract categories ---
    categories = CATEGORY_PATTERN.findall(text)

    # --- Extract links ---
    links = LINK_PATTERN.findall(text)
    # Remove duplicates, ignore File/Image prefixes
    links = list({
        link.strip()
        for link in links
        if not link.lower().startswith(("file:", "image:", "category:"))
    })

    # --- Extract section titles ---
    sections = SECTION_PATTERN.findall(text)

    # --- Clean categories and sections ---
    categories = [c.strip() for c in categories if c.strip()]
    sections = [s.strip() for s in sections if s.strip()]

    return {
        "title": title,
        "links": links,
        "categories": categories,
        "sections": sections,
        "text": text.strip()
    }


def main():
    parsed_data = []

    files = [f for f in os.listdir(INPUT_DIR) if f.endswith(".txt")]
    total = len(files)
    print(f"Parsing {total} wikitext files...")

    for i, filename in enumerate(files, start=1):
        path = os.path.join(INPUT_DIR, filename)
        with open(path, encoding="utf-8") as f:
            text = f.read()

        title = filename.replace(".txt", "")
        parsed = parse_wikitext(title, text)
        parsed_data.append(parsed)

        if i % 50 == 0 or i == total:
            print(f"[{i}/{total}] Processed {filename}")

    # --- Save consolidated JSON ---
    os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)
    with open(OUTPUT_PATH, "w", encoding="utf-8") as f:
        json.dump(parsed_data, f, ensure_ascii=False, indent=2)

    print(f"\n✅ Done. Saved parsed data to: {OUTPUT_PATH}")
    print(f"Entries parsed: {len(parsed_data)}")

main()
# Out:
# Parsing 1161 wikitext files...
# [50/1161] Processed Lactarius_vietus.txt
# [100/1161] Processed Gymnopilus_subfulvus.txt
# [150/1161] Processed Fomitopsis_pinicola.txt
# [200/1161] Processed Gymnopilus_maritimus.txt
# [250/1161] Processed Coprinopsis_nivea.txt
# [300/1161] Processed Gymnopilus_bellulus.txt
# [350/1161] Processed Ganoderma_sichuanense.txt
# [400/1161] Processed Inocybe_geophylla.txt
# [450/1161] Processed Gymnopilus_purpureonitens.txt
# [500/1161] Processed Gymnopilus_panelloides.txt
# [550/1161] Processed Gymnopilus_communis.txt
# [600/1161] Processed Russula_risigallina.txt
# [650/1161] Processed Thelephora_terrestris.txt
# [700/1161] Processed Mycena_overholtsii.txt
# [750/1161] Processed Clathrus_columnatus.txt
# [800/1161] Processed Lactarius_affinis.txt
# [850/1161] Processed Cantharellus_cascadensis.txt
# [900/1161] Processed Hericium_cirrhatum.txt
# [950/1161] Processed Russula_versicolor.txt
# [1000/1161] Processed Agaricus_pattersoniae.txt
# [1050/1161] Processed Cortinarius_delibutus.txt
# [1100/1161] Processed Suillus_lakei.txt
# [1150/1161] Processed Ramaria_stricta.txt
# [1161/1161] Processed Pleurotus_citrinopileatus.txt
#
# ✅ Done. Saved parsed data to: data/parsed_wikitext_data.json
# Entries parsed: 1161

# %%
import os

folder = "data/raw_articles_wikitext"
sizes = [(f, os.path.getsize(os.path.join(folder, f))) for f in os.listdir(folder)]
sizes.sort(key=lambda x: x[1])
print("Smallest 10 files:")
for f, s in sizes[:10]:
    print(f"{f}: {s} bytes")

print("\nLargest 10 files:")
for f, s in sizes[-10:]:
    print(f"{f}: {s} bytes")
# Out:
# Smallest 10 files:
# Leccinellum_pseudoscabrum.txt: 838 bytes
# Lactarius_azonites.txt: 843 bytes
# Amanita_lividopallescens.txt: 882 bytes
# Amanita_proxima.txt: 933 bytes
# Ramaria_aurea.txt: 957 bytes
# Lactarius_semisanguifluus.txt: 1052 bytes
# Mycena_vinacea.txt: 1135 bytes
# Mycena_kuurkacea.txt: 1235 bytes
# Macrocybe_spectabilis.txt: 1317 bytes
# Cantharellus_appalachiensis.txt: 1423 bytes
#
# Largest 10 files:
# Lactifluus_volemus.txt: 43243 bytes
# Paxillus_involutus.txt: 49583 bytes
# Suillus_luteus.txt: 49797 bytes
# Phallus_indusiatus.txt: 50000 bytes
# Suillellus_luridus.txt: 54957 bytes
# Armillaria_gallica.txt: 55593 bytes
# Psilocybe_semilanceata.txt: 57240 bytes
# Amanita_phalloides.txt: 61751 bytes
# Amanita_muscaria.txt: 82606 bytes
# Boletus_edulis.txt: 86824 bytes

# %%
import os
files = [f for f in os.listdir("data/raw_articles_wikitext") if f.endswith(".txt")]
print(len(files))

# Print the ones that does not end with .txt
for f in os.listdir("data/raw_articles_wikitext"):
    if not f.endswith(".txt"):
        print(f)
# Out:
# 531

# %%
# Print number of files in raw_articles_wikitext
print(f"Number of files in raw_articles_wikitext: {len(os.listdir('data/raw_articles_wikitext'))}")
# Out:
# Number of files in raw_articles_wikitext: 531
